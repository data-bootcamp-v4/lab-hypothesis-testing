# %% [markdown]
# # Lab | Hypothesis Testing

# %% [markdown]
# **Objective**
#
# Welcome to the Hypothesis Testing Lab, where we embark on an enlightening journey through the realm of statistical decision-making! In this laboratory, we delve into various scenarios, applying the powerful tools of hypothesis testing to scrutinize and interpret data.
#
# From testing the mean of a single sample (One Sample T-Test), to investigating differences between independent groups (Two Sample T-Test), and exploring relationships within dependent samples (Paired Sample T-Test), our exploration knows no bounds. Furthermore, we'll venture into the realm of Analysis of Variance (ANOVA), unraveling the complexities of comparing means across multiple groups.
#
# So, grab your statistical tools, prepare your hypotheses, and let's embark on this fascinating journey of exploration and discovery in the world of hypothesis testing!

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# In this challenge, we will be working with pokemon data. The data can be found here:
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv

# %%
#libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import plotly.express as px
import math 
# !pip install haversine
# Out:
# Requirement already satisfied: haversine in c:\users\utilisateur\anaconda3\lib\site-packages (2.9.0)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv")
df
# Out:
#                Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0         Bulbasaur    Grass  Poison  45      49       49       65       65
# 1           Ivysaur    Grass  Poison  60      62       63       80       80
# 2          Venusaur    Grass  Poison  80      82       83      100      100
# 3     Mega Venusaur    Grass  Poison  80     100      123      122      120
# 4        Charmander     Fire     NaN  39      52       43       60       50
# ..              ...      ...     ...  ..     ...      ...      ...      ...
# 795         Diancie     Rock   Fairy  50     100      150      100      150
# 796    Mega Diancie     Rock   Fairy  50     160      110      160      110
# 797  Hoopa Confined  Psychic   Ghost  80     110       60      150      130
# 798   Hoopa Unbound  Psychic    Dark  80     160       60      170      130
# 799       Volcanion     Fire   Water  80     110      120      130       90
#
#      Speed  Generation  Legendary
# 0       45           1      False
# 1       60           1      False
# 2       80           1      False
# 3       80           1      False
# 4       65           1      False
# ..     ...         ...        ...
# 795     50           6       True
# 796    110           6       True
# 797     70           6       True
# 798     80           6       True
# 799     70           6       True
#
# [800 rows x 11 columns]

# %% [markdown]
# - We posit that Pokemons of type Dragon have, on average, more HP stats than Grass. Choose the propper test and, with 5% significance, comment your findings.

# %%
def show_statistical_test(statistic: float, alpha: float, n: int, distribution: str=["t-student","normal"], alternative: str=["two-sided","lower","greater"]):

    if distribution not in ["t-student","normal"]:
        raise TypeError("Sorry, only 't-student', and 'normal' distributions are acepted")

    if alternative not in ["two-sided","lower","greater"]:
        raise TypeError("Sorry, only 'two-sided', 'lower', and 'greated' are acepted valued for the alternative")

    if not isinstance(statistic, float):
        raise TypeError("Sorry, the data type for the statistic must be float")

    if not isinstance(alpha, float):
        raise TypeError("Sorry, the data type for alpha must be float")

    if not isinstance(n, int):
        raise TypeError("Sorry, the data type for n must be int")

    x_values = np.linspace(-3, 3)

    if distribution == "t-student":

        y_values = st.t.pdf(x_values, df=n-1)

        if alternative == "two-sided": # Computing the critical values

            lower_critical_value = st.t.ppf(alpha/2, df=n-1)
            upper_critical_value = st.t.ppf(1-(alpha/2), df=n-1)

            x_values1 = np.linspace(-3, lower_critical_value)
            y_values1 = st.t.pdf(x_values1, df=n-1)

            x_values2 = np.linspace(upper_critical_value, 3)
            y_values2 = st.t.pdf(x_values2, df=n-1)

        elif alternative == "lower":

            critical_value = st.t.ppf(alpha, df=n-1)

            x_values1 = np.linspace(-3, critical_value)
            y_values1 = st.t.pdf(x_values1, df=n-1)

        elif alternative == "greater":

            critical_value = st.t.ppf(1-alpha, df=n-1)

            x_values2 = np.linspace(critical_value, 3)
            y_values2 = st.t.pdf(x_values2, df=n-1)

    elif distribution == "normal":

        y_values = st.norm.pdf(x_values)

        if alternative == "two-sided": # Computing the critical values

            lower_critical_value = st.norm.ppf(alpha/2)
            upper_critical_value = st.norm.ppf(1-(alpha/2))

            x_values1 = np.linspace(-3, lower_critical_value)
            y_values1 = st.norm.pdf(x_values1)

            x_values2 = np.linspace(upper_critical_value, 3)
            y_values2 = st.norm.pdf(x_values2)

        elif alternative == "lower":

            critical_value = st.norm.ppf(alpha)

            x_values1 = np.linspace(-3, critical_value)
            y_values1 = st.norm.pdf(x_values1)

        elif alternative == "greater":

            critical_value = st.norm.ppf(1-alpha)

            x_values2 = np.linspace(critical_value, 3)
            y_values2 = st.norm.pdf(x_values2)

    df = pd.DataFrame({"x": x_values, "pdf": y_values})

    title = f"{distribution} Probability Density Function"

    fig = px.line(df, x="x", y="pdf", title=title)

    if alternative == "two-sided":

        fig.add_vline(x=lower_critical_value, line_color="red")
        fig.add_vline(x=upper_critical_value, line_color="red")

        fig.add_annotation(x=lower_critical_value,y=0,text=f"Lower critical value {lower_critical_value: .2f}",xref="x",yref="paper",yanchor="bottom")
        fig.add_annotation(x=upper_critical_value,y=0,text=f"Upper critical value {upper_critical_value: .2f}",xref="x",yref="paper",yanchor="bottom")

        fig.add_scatter(x=x_values1, y=y_values1,fill='tozeroy', mode='none' , fillcolor='red')
        fig.add_scatter(x=x_values2, y=y_values2,fill='tozeroy', mode='none' , fillcolor='red')

    elif alternative == "lower":

        fig.add_vline(x=critical_value, line_color="red")
        fig.add_annotation(x=critical_value,y=0,text=f"Critical value {critical_value: .2f}",xref="x",yref="paper",yanchor="bottom")

        fig.add_scatter(x=x_values1, y=y_values1,fill='tozeroy', mode='none' , fillcolor='red')

    elif alternative == "greater":

        fig.add_vline(x=critical_value, line_color="red")
        fig.add_annotation(x=critical_value,y=0,text=f"Critical value {critical_value: .2f}",xref="x",yref="paper",yanchor="bottom")

        fig.add_scatter(x=x_values2, y=y_values2,fill='tozeroy', mode='none' , fillcolor='red')

    fig.add_vline(x=statistic)
    fig.add_annotation(x=statistic,y=0,text=f"Statistic {statistic: .2f}",xref="x",yref="paper",yanchor="bottom")

    fig.update_layout(title_text=f'{distribution} Probability Density Function', title_x=0.5)

    fig.update_layout(showlegend=False)

    fig.show()

# %%
# create 2 groups
df_dragon = df[df["Type 1"]=="Dragon"]["HP"]
df_grass = df[df["Type 1"]=="Grass"]["HP"]

# %%
#Set the hypothesis

#H0: mu_hp dragon =< mu_hp grass
#H1: mu_hp dragon > mu_hp grass  

#H0: mu_hp dragon - mu_hp grass = 0 = delta
#H1: mu_hp dragon - mu_hp grass != 0 = delta

#significance level (alpha) = 0.05

# %%
dragon_mean = df_dragon.mean()
grass_mean = df_grass.mean()

dragon_std = df_dragon.std(ddof=1)
grass_std = df_grass.std(ddof=1)

n1 = len(df_dragon)
n2 = len(df_grass)

statistic = (dragon_mean - grass_mean) / np.sqrt( (dragon_std**2/n1) + (grass_std**2/n2))
statistic
# Out:
# np.float64(3.334963290512407)

# %%
show_statistical_test(statistic, 0.05, n1+n2-2, distribution="t-student", alternative="greater")

# %%
#Two sampled Test
st.ttest_ind(df_dragon,df_grass, equal_var=False, alternative="greater")
# Out:
# TtestResult(statistic=np.float64(3.3349632905124063), pvalue=np.float64(0.0007993609745420599), df=np.float64(50.83784116232685))

# %% [markdown]
# Dragon Pokémon have, on average, higher values than Grass Pokémon, and this difference is very likely real and not due to chance.

# %% [markdown]
# - We posit that Legendary Pokemons have different stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) when comparing with Non-Legendary. Choose the propper test and, with 5% significance, comment your findings.

# %%
#Set the hypothesis

#H0: legendary = non legendary
#H1: legendary != non legendary

#significance level (alpha) = 0.05

# %%
# create 2 groups
stats = ["HP", "Attack", "Defense", 'Sp. Atk', 'Sp. Def', "Speed"] # helped by AI a lot here
df_lgd = df[(df["Legendary"]== True)] 
df_non_lgd = df[(df["Legendary"]==False)]
alpha = 0.05

# create a df based on results of ttest (two samples)
for stat in stats:
    result = st.ttest_ind(df_lgd[stat],df_non_lgd[stat], equal_var=False, alternative="two-sided")
    statistic = result.statistic
    p = result.pvalue
    if p > alpha:
        print(f"{stat}: statistic = {result.statistic:.3f}, p = {result.pvalue:.10e}")
        print("We are not able to reject the null hypothesis")
    else:
        print(f"{stat}: statistic = {result.statistic:.3f}, p = {result.pvalue:.10e}")
        print("We reject the null hypothesis")
# Out:
# HP: statistic = 8.981, p = 1.0026911708e-13
# We reject the null hypothesis
# Attack: statistic = 10.438, p = 2.5203724492e-16
# We reject the null hypothesis
# Defense: statistic = 7.637, p = 4.8269984949e-11
# We reject the null hypothesis
# Sp. Atk: statistic = 13.417, p = 1.5514614112e-21
# We reject the null hypothesis
# Sp. Def: statistic = 10.016, p = 2.2949327864e-15
# We reject the null hypothesis
# Speed: statistic = 11.475, p = 1.0490163119e-18
# We reject the null hypothesis

# %% [markdown]
# Here i have been helped a lot by AI because it would have been really long to do it one by one.
# This is really interesting because now we can evaluate the significance of each variable directly.
# The null hypothesis is rejected for each variable because the p-value is always under alpha, means there is a significant difference between legendary and non legendary pokemon

# %% [markdown]
# **Challenge 2**

# %% [markdown]
# In this challenge, we will be working with california-housing data. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# **We posit that houses close to either a school or a hospital are more expensive.**
#
# - School coordinates (-118, 34)
# - Hospital coordinates (-122, 37)
#
# We consider a house (neighborhood) to be close to a school or hospital if the distance is lower than 0.50.
#
# Hint:
# - Write a function to calculate euclidean distance from each house (neighborhood) to the school and to the hospital.
# - Divide your dataset into houses close and far from either a hospital or school.
# - Choose the propper test and, with 5% significance, comment your findings.

# %%
from haversine import haversine, Unit

# Public services coordinates
school = (34,-118)
hospital = (37,-122)

# write a function to calculate distance between each house and a school and/or hospital (1st version)
def euclidean_distance(df, school, hospital):
    d_school = []
    d_hospital = []
    for lat, lon in zip(df['latitude'],df['longitude']):
        latlon = (lat,lon)
        d1 = haversine(school,latlon, unit=Unit.MILES)
        d2 = haversine(hospital,latlon, unit=Unit.MILES)
        d_school.append(d1)
        d_hospital.append(d2)
    df['d_school'] = d_school
    df['d_hospital'] = d_hospital
    return df

euclidean_distance(df, school, hospital)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value    d_school  \
# 0          1015.0       472.0         1.4936             66900.0  211.526424
# 1          1129.0       463.0         1.8200             80100.0  203.598237
# 2           333.0       117.0         1.6509             85700.0  198.554510
# 3           515.0       226.0         3.1917             73400.0  198.444503
# 4           624.0       262.0         1.9250             65500.0  199.187889
# ...           ...         ...            ...                 ...         ...
# 16995       907.0       369.0         2.3571            111400.0  569.826936
# 16996      1194.0       465.0         2.5179             79000.0  576.074782
# 16997      1244.0       456.0         3.0313            103600.0  640.921274
# 16998      1298.0       478.0         1.9797             85800.0  638.641652
# 16999       806.0       270.0         3.0147             94600.0  570.686548
#
#        d_hospital
# 0      473.468963
# 1      458.930041
# 2      477.405015
# 3      478.686745
# 4      481.203430
# ...           ...
# 16995  275.650161
# 16996  282.679980
# 16997  356.194385
# 16998  353.613814
# 16999  275.381199
#
# [17000 rows x 11 columns]

# %%
# best way would be a list comprehension with zip (much faster than apply, lambda) and also create only once coords
def euclidean_distance(df, school, hospital):
    coords =  list(zip(df['latitude'],df['longitude']))
    df['d_school'] = [
    haversine(school, coord, unit=Unit.MILES)
    for coord in coords]
    df['d_hospital'] = [
    haversine(hospital, coord, unit=Unit.MILES)
    for coord in coords]
    return df


euclidean_distance(df, school, hospital)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value    d_school  \
# 0          1015.0       472.0         1.4936             66900.0  211.526424
# 1          1129.0       463.0         1.8200             80100.0  203.598237
# 2           333.0       117.0         1.6509             85700.0  198.554510
# 3           515.0       226.0         3.1917             73400.0  198.444503
# 4           624.0       262.0         1.9250             65500.0  199.187889
# ...           ...         ...            ...                 ...         ...
# 16995       907.0       369.0         2.3571            111400.0  569.826936
# 16996      1194.0       465.0         2.5179             79000.0  576.074782
# 16997      1244.0       456.0         3.0313            103600.0  640.921274
# 16998      1298.0       478.0         1.9797             85800.0  638.641652
# 16999       806.0       270.0         3.0147             94600.0  570.686548
#
#        d_hospital
# 0      473.468963
# 1      458.930041
# 2      477.405015
# 3      478.686745
# 4      481.203430
# ...           ...
# 16995  275.650161
# 16996  282.679980
# 16997  356.194385
# 16998  353.613814
# 16999  275.381199
#
# [17000 rows x 11 columns]

# %%
# create 2 df whose houses are either close or far from
df_close = df[(df['d_school'] <= 5) | (df['d_hospital'] <= 5)]['median_house_value']
df_far = df[~(df['d_school'] <= 5) | (df['d_hospital'] <= 5)]['median_house_value']

# %%
df_close
# Out:
# 3638     127200.0
# 3639     136300.0
# 3640     362500.0
# 3713     181000.0
# 3714     163100.0
#            ...
# 14071    294100.0
# 14072    226500.0
# 14119    131300.0
# 14120    258300.0
# 14254    203700.0
# Name: median_house_value, Length: 295, dtype: float64

# %%
df_far
# Out:
# 0         66900.0
# 1         80100.0
# 2         85700.0
# 3         73400.0
# 4         65500.0
#            ...
# 16995    111400.0
# 16996     79000.0
# 16997    103600.0
# 16998     85800.0
# 16999     94600.0
# Name: median_house_value, Length: 16782, dtype: float64

# %%
#Set the hypothesis that the houses closer to a shcool and/or a hospital are more expensive than further

#H0: df_close value <= df_far value
#H1: df_close value > df_far value

#significance level (alpha) = 0.05

# %%
# compare the median_house_value between the 2 groups using a t test 
df_close_mean = df_close.mean()
df_far_mean = df_far.mean()

df_close_std = df_close.std(ddof=1)
df_far_std = df_far.std(ddof=1)

n1 = len(df_close)
n2 = len(df_far)

statistic = (df_close_mean - df_far_mean) / np.sqrt( (df_close_std**2/n1) + (df_far_std**2/n2))
statistic
# Out:
# np.float64(1.1504662486597894)

# %%
# create a graph based on function
show_statistical_test(statistic, 0.05, n1+n2-2, distribution="t-student", alternative="greater")

# %%
# create a t-test with the scipy of python
st.ttest_ind(df_close,df_far, equal_var=False, alternative="greater")
# Out:
# TtestResult(statistic=np.float64(1.1504662486597885), pvalue=np.float64(0.12540538727241773), df=np.float64(320.03736698080047))

# %%
# extract the pvalue from the result
p_value = st.ttest_ind(df_close,df_far, equal_var=False, alternative="greater").pvalue

# get the final decision
if p_value > alpha:
    print("We are not able to reject the null hypothesis")
else:
    print("We reject the null hypothesis")
# Out:
# We are not able to reject the null hypothesis

# %% [markdown]
# According to our results, the houses closer to a hospital or a school (5 miles) are not more expensive than further houses.
