# %% [markdown]
# # Lab | Hypothesis Testing

# %% [markdown]
# **Objective**
#
# Welcome to the Hypothesis Testing Lab, where we embark on an enlightening journey through the realm of statistical decision-making! In this laboratory, we delve into various scenarios, applying the powerful tools of hypothesis testing to scrutinize and interpret data.
#
# From testing the mean of a single sample (One Sample T-Test), to investigating differences between independent groups (Two Sample T-Test), and exploring relationships within dependent samples (Paired Sample T-Test), our exploration knows no bounds. Furthermore, we'll venture into the realm of Analysis of Variance (ANOVA), unraveling the complexities of comparing means across multiple groups.
#
# So, grab your statistical tools, prepare your hypotheses, and let's embark on this fascinating journey of exploration and discovery in the world of hypothesis testing!

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# In this challenge, we will be working with pokemon data. The data can be found here:
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv

# %%
#libraries
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy import stats

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv")
df
# Out:
#                Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0         Bulbasaur    Grass  Poison  45      49       49       65       65
# 1           Ivysaur    Grass  Poison  60      62       63       80       80
# 2          Venusaur    Grass  Poison  80      82       83      100      100
# 3     Mega Venusaur    Grass  Poison  80     100      123      122      120
# 4        Charmander     Fire     NaN  39      52       43       60       50
# ..              ...      ...     ...  ..     ...      ...      ...      ...
# 795         Diancie     Rock   Fairy  50     100      150      100      150
# 796    Mega Diancie     Rock   Fairy  50     160      110      160      110
# 797  Hoopa Confined  Psychic   Ghost  80     110       60      150      130
# 798   Hoopa Unbound  Psychic    Dark  80     160       60      170      130
# 799       Volcanion     Fire   Water  80     110      120      130       90
#
#      Speed  Generation  Legendary
# 0       45           1      False
# 1       60           1      False
# 2       80           1      False
# 3       80           1      False
# 4       65           1      False
# ..     ...         ...        ...
# 795     50           6       True
# 796    110           6       True
# 797     70           6       True
# 798     80           6       True
# 799     70           6       True
#
# [800 rows x 11 columns]

# %%
df.columns = (
    df.columns
    .str.lower()
    .str.replace('(', '_', regex=False)   # replace ( with _
    .str.replace('/', '_', regex=False)   # replace ( with _
    .str.replace(')', '', regex=False)    # remove )
    .str.replace(r'[^\w\s]', '', regex=True)  # remove other special chars
    .str.replace(' ', '_')                # spaces → underscore
    .str.replace('__', '_')
)
df.columns
# Out:
# Index(['name', 'type_1', 'type_2', 'hp', 'attack', 'defense', 'sp_atk',
#        'sp_def', 'speed', 'generation', 'legendary'],
#       dtype='object')

# %%
print("\n", "Head:","\n", df.head(5))
print("\n", "Tail:","\n", df.tail(5))
print("\n", "Info:","\n", df.info())
print("\n", "Info Memory Usage:","\n", df.info(memory_usage="deep"))
print("\n", "Describe:","\n", df.describe())
print("\n", "Describe All:","\n", df.describe(include="all"))
print("\n", "Shape:","\n", df.shape)
print("\n", "DTypes:","\n", df.dtypes)
print("\n", "Columns:","\n", df.columns)
print("\n", "Index:","\n", df.index)
print("\n", "Values:","\n", df.values)
print("\n", "Empty:","\n", df.empty)
print("\n", "NDim:","\n", df.ndim)
print("\n", "Size:","\n", df.size)
print("\n", "Memory True:","\n", df.memory_usage(deep=True))
print("\n", "Transpose:","\n", df.T)
# Out:
#  Head:
#              name type_1  type_2  hp  attack  defense  sp_atk  sp_def  speed  \
# 0      Bulbasaur  Grass  Poison  45      49       49      65      65     45
# 1        Ivysaur  Grass  Poison  60      62       63      80      80     60
# 2       Venusaur  Grass  Poison  80      82       83     100     100     80
# 3  Mega Venusaur  Grass  Poison  80     100      123     122     120     80
# 4     Charmander   Fire     NaN  39      52       43      60      50     65
#
#    generation  legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
#
#  Tail:
#                 name   type_1 type_2  hp  attack  defense  sp_atk  sp_def  \
# 795         Diancie     Rock  Fairy  50     100      150     100     150
# 796    Mega Diancie     Rock  Fairy  50     160      110     160     110
# 797  Hoopa Confined  Psychic  Ghost  80     110       60     150     130
# 798   Hoopa Unbound  Psychic   Dark  80     160       60     170     130
# 799       Volcanion     Fire  Water  80     110      120     130      90
#
#      speed  generation  legendary
# 795     50           6       True
# 796    110           6       True
# 797     70           6       True
# 798     80           6       True
# 799     70           6       True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        799 non-null    object
#  1   type_1      800 non-null    object
#  2   type_2      414 non-null    object
#  3   hp          800 non-null    int64
#  4   attack      800 non-null    int64
#  5   defense     800 non-null    int64
#  6   sp_atk      800 non-null    int64
#  7   sp_def      800 non-null    int64
#  8   speed       800 non-null    int64
#  9   generation  800 non-null    int64
#  10  legendary   800 non-null    bool
# dtypes: bool(1), int64(7), object(3)
# memory usage: 63.4+ KB
#
#  Info:
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        799 non-null    object
#  1   type_1      800 non-null    object
#  2   type_2      414 non-null    object
#  3   hp          800 non-null    int64
#  4   attack      800 non-null    int64
#  5   defense     800 non-null    int64
#  6   sp_atk      800 non-null    int64
#  7   sp_def      800 non-null    int64
#  8   speed       800 non-null    int64
#  9   generation  800 non-null    int64
#  10  legendary   800 non-null    bool
# dtypes: bool(1), int64(7), object(3)
# memory usage: 166.1 KB
#
#  Info Memory Usage:
#  None
#
#  Describe:
#                 hp      attack     defense      sp_atk      sp_def       speed  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean    69.258750   79.001250   73.842500   72.820000   71.902500   68.277500
# std     25.534669   32.457366   31.183501   32.722294   27.828916   29.060474
# min      1.000000    5.000000    5.000000   10.000000   20.000000    5.000000
# 25%     50.000000   55.000000   50.000000   49.750000   50.000000   45.000000
# 50%     65.000000   75.000000   70.000000   65.000000   70.000000   65.000000
# 75%     80.000000  100.000000   90.000000   95.000000   90.000000   90.000000
# max    255.000000  190.000000  230.000000  194.000000  230.000000  180.000000
#
#        generation
# count   800.00000
# mean      3.32375
# std       1.66129
# min       1.00000
# 25%       2.00000
# 50%       3.00000
# 75%       5.00000
# max       6.00000
#
#  Describe All:
#               name type_1  type_2          hp      attack     defense  \
# count         799    800     414  800.000000  800.000000  800.000000
# unique        799     18      18         NaN         NaN         NaN
# top     Bulbasaur  Water  Flying         NaN         NaN         NaN
# freq            1    112      97         NaN         NaN         NaN
# mean          NaN    NaN     NaN   69.258750   79.001250   73.842500
# std           NaN    NaN     NaN   25.534669   32.457366   31.183501
# min           NaN    NaN     NaN    1.000000    5.000000    5.000000
# 25%           NaN    NaN     NaN   50.000000   55.000000   50.000000
# 50%           NaN    NaN     NaN   65.000000   75.000000   70.000000
# 75%           NaN    NaN     NaN   80.000000  100.000000   90.000000
# max           NaN    NaN     NaN  255.000000  190.000000  230.000000
#
#             sp_atk      sp_def       speed  generation legendary
# count   800.000000  800.000000  800.000000   800.00000       800
# unique         NaN         NaN         NaN         NaN         2
# top            NaN         NaN         NaN         NaN     False
# freq           NaN         NaN         NaN         NaN       735
# mean     72.820000   71.902500   68.277500     3.32375       NaN
# std      32.722294   27.828916   29.060474     1.66129       NaN
# min      10.000000   20.000000    5.000000     1.00000       NaN
# 25%      49.750000   50.000000   45.000000     2.00000       NaN
# 50%      65.000000   70.000000   65.000000     3.00000       NaN
# 75%      95.000000   90.000000   90.000000     5.00000       NaN
# max     194.000000  230.000000  180.000000     6.00000       NaN
#
#  Shape:
#  (800, 11)
#
#  DTypes:
#  name          object
# type_1        object
# type_2        object
# hp             int64
# attack         int64
# defense        int64
# sp_atk         int64
# sp_def         int64
# speed          int64
# generation     int64
# legendary       bool
# dtype: object
#
#  Columns:
#  Index(['name', 'type_1', 'type_2', 'hp', 'attack', 'defense', 'sp_atk',
#        'sp_def', 'speed', 'generation', 'legendary'],
#       dtype='object')
#
#  Index:
#  RangeIndex(start=0, stop=800, step=1)
#
#  Values:
#  [['Bulbasaur' 'Grass' 'Poison' ... 45 1 False]
#  ['Ivysaur' 'Grass' 'Poison' ... 60 1 False]
#  ['Venusaur' 'Grass' 'Poison' ... 80 1 False]
#  ...
#  ['Hoopa Confined' 'Psychic' 'Ghost' ... 70 6 True]
#  ['Hoopa Unbound' 'Psychic' 'Dark' ... 80 6 True]
#  ['Volcanion' 'Fire' 'Water' ... 70 6 True]]
#
#  Empty:
#  False
#
#  NDim:
#  2
#
#  Size:
#  8800
#
#  Memory True:
#  Index           132
# name          45941
# type_1        43408
# type_2        34978
# hp             6400
# attack         6400
# defense        6400
# sp_atk         6400
# sp_def         6400
# speed          6400
# generation     6400
# legendary       800
# dtype: int64
#
#  Transpose:
#                    0        1         2              3           4    \
# name        Bulbasaur  Ivysaur  Venusaur  Mega Venusaur  Charmander
# type_1          Grass    Grass     Grass          Grass        Fire
# type_2         Poison   Poison    Poison         Poison         NaN
# hp                 45       60        80             80          39
# attack             49       62        82            100          52
# defense            49       63        83            123          43
# sp_atk             65       80       100            122          60
# sp_def             65       80       100            120          50
# speed              45       60        80             80          65
# generation          1        1         1              1           1
# legendary       False    False     False          False       False
#
#                    5          6                 7                 8    \
# name        Charmeleon  Charizard  Mega Charizard X  Mega Charizard Y
# type_1            Fire       Fire              Fire              Fire
# type_2             NaN     Flying            Dragon            Flying
# hp                  58         78                78                78
# attack              64         84               130               104
# defense             58         78               111                78
# sp_atk              80        109               130               159
# sp_def              65         85                85               115
# speed               80        100               100               100
# generation           1          1                 1                 1
# legendary        False      False             False             False
#
#                  9    ...     790      791      792      793  \
# name        Squirtle  ...  Noibat  Noivern  Xerneas  Yveltal
# type_1         Water  ...  Flying   Flying    Fairy     Dark
# type_2           NaN  ...  Dragon   Dragon      NaN   Flying
# hp                44  ...      40       85      126      126
# attack            48  ...      30       70      131      131
# defense           65  ...      35       80       95       95
# sp_atk            50  ...      45       97      131      131
# sp_def            64  ...      40       80       98       98
# speed             43  ...      55      123       99       99
# generation         1  ...       6        6        6        6
# legendary      False  ...   False    False     True     True
#
#                            794      795           796             797  \
# name        Zygarde Half Forme  Diancie  Mega Diancie  Hoopa Confined
# type_1                  Dragon     Rock          Rock         Psychic
# type_2                  Ground    Fairy         Fairy           Ghost
# hp                         108       50            50              80
# attack                     100      100           160             110
# defense                    121      150           110              60
# sp_atk                      81      100           160             150
# sp_def                      95      150           110             130
# speed                       95       50           110              70
# generation                   6        6             6               6
# legendary                 True     True          True            True
#
#                       798        799
# name        Hoopa Unbound  Volcanion
# type_1            Psychic       Fire
# type_2               Dark      Water
# hp                     80         80
# attack                160        110
# defense                60        120
# sp_atk                170        130
# sp_def                130         90
# speed                  80         70
# generation              6          6
# legendary            True       True
#
# [11 rows x 800 columns]

# %% [markdown]
# - We posit that Pokemons of type Dragon have, on average, more HP stats than Grass. Choose the propper test and, with 5% significance, comment your findings.
#
# - #H0:HP_dragon = HP_Grass
# - #H1: HP_dragon >= HP_Grass

# %%
hp_dragon = df[df["type_1"]== "Dragon"]["hp"]
hp_dragon

hp_Grass = df[df["type_1"]== "Grass"]["hp"]
hp_Grass
alpha = 0.05

results = stats.ttest_ind(df[df.type_1=='Dragon'].hp, df[df.type_1=='Grass'].hp)
p_value = results.pvalue


if p_value > alpha:
    print("We are not able to reject the null hypothesis")
else:
    print("We reject the null hypothesis, meaning that HP_dragon >= HP_Grass")
# Out:
# We reject the null hypothesis

# %% [markdown]
# - We posit that Legendary Pokemons have different stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) when comparing with Non-Legendary. Choose the propper test and, with 5% significance, comment your findings.

# %%
#code here
H0: lengendar stats = legendary_not stats
H0: lengendar stats >= legendary_not stats

legend = df[df["legendary"]==True]
#hp  attack  defense  sp_atk  sp_def  speed

legend_not = df[df["legendary"]==False]
#hp  attack  defense  sp_atk  sp_def  speed

p_hp = stats.ttest_ind(legend["hp"], legend_not["hp"], equal_var=False).pvalue
p_attack = stats.ttest_ind(legend["attack"], legend_not["attack"], equal_var=False).pvalue
p_defense = stats.ttest_ind(legend["defense"], legend_not["defense"], equal_var=False).pvalue
p_sp_atk = stats.ttest_ind(legend["sp_atk"], legend_not["sp_atk"], equal_var=False).pvalue
p_sp_def = stats.ttest_ind(legend["sp_def"], legend_not["sp_def"], equal_var=False).pvalue
p_speed = stats.ttest_ind(legend["speed"], legend_not["speed"], equal_var=False).pvalue


if p_hp > alpha:
    print("We are not able to reject the null hypothesis")
if p_attack > alpha:
    print("We are not able to reject the null hypothesis")
if p_defense > alpha:
    print("We are not able to reject the null hypothesis")
if p_sp_atk > alpha:
    print("We are not able to reject the null hypothesis")
if p_sp_def > alpha:
    print("We are not able to reject the null hypothesis")
if p_speed > alpha:
    print("We are not able to reject the null hypothesis")

if p_hp < alpha:
    print("ph_We are not able to reject the null hypothesis")
if p_attack < alpha:
    print("p_attack We are  able to reject the null hypothesis")
if p_defense < alpha:
    print("p_defense We are  able to reject the null hypothesis")
if p_sp_atk < alpha:
    print(" p_sp_atk We  not able to reject the null hypothesis")
if p_sp_def < alpha:
    print("p_sp_def We  not able to reject the null hypothesis")
if p_speed < alpha:
    print("p_speed We  not able to reject the null hypothesis")
else:
    print("nothing")
# Out:
# ph_We are not able to reject the null hypothesis
# p_attack We are  able to reject the null hypothesis
# p_defense We are  able to reject the null hypothesis
#  p_sp_atk We  not able to reject the null hypothesis
# p_sp_def We  not able to reject the null hypothesis
# p_speed We  not able to reject the null hypothesis

# %%
print("\n", "Head:","\n", df.head(5))

p_value = stats.ttest_ind(df[df.type_1=='Dragon'].hp, df[df.type_1=='Grass'].hp).pvalue
# Out:
#  Head:
#              name type_1  type_2  hp  attack  defense  sp_atk  sp_def  speed  \
# 0      Bulbasaur  Grass  Poison  45      49       49      65      65     45
# 1        Ivysaur  Grass  Poison  60      62       63      80      80     60
# 2       Venusaur  Grass  Poison  80      82       83     100     100     80
# 3  Mega Venusaur  Grass  Poison  80     100      123     122     120     80
# 4     Charmander   Fire     NaN  39      52       43      60      50     65
#
#    generation  legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False

# %% [markdown]
# **Challenge 2**

# %% [markdown]
# In this challenge, we will be working with california-housing data. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv

# %%
df_2 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# **We posit that houses close to either a school or a hospital are more expensive.**
#
# - School coordinates (-118, 34)
# - Hospital coordinates (-122, 37)
#
# We consider a house (neighborhood) to be close to a school or hospital if the distance is lower than 0.50.
#
# Hint:
# - Write a function to calculate euclidean distance from each house (neighborhood) to the school and to the hospital.
# - Divide your dataset into houses close and far from either a hospital or school.
# - Choose the propper test and, with 5% significance, comment your findings.

# %%
def euclidean_distance(row, x2, y2):
    x1, y1 = row["longitude"], row["latitude"]
    return np.sqrt((x2 - x1)**2 + (y2 - y1)**2)

# Distance to school and hospital (new columns)
df_2["dist_school"] = df.apply(lambda row: euclidean_distance(row, school[0], school[1]), axis=1)
df_2["dist_hospital"] = df.apply(lambda row: euclidean_distance(row, hospital[0], hospital[1]), axis=1)
df_2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  dist_school  \
# 0          1015.0       472.0         1.4936             66900.0     3.694888
# 1          1129.0       463.0         1.8200             80100.0     3.552591
# 2           333.0       117.0         1.6509             85700.0     3.453940
# 3           515.0       226.0         3.1917             73400.0     3.448840
# 4           624.0       262.0         1.9250             65500.0     3.456848
# ...           ...         ...            ...                 ...          ...
# 16995       907.0       369.0         2.3571            111400.0     9.082070
# 16996      1194.0       465.0         2.5179             79000.0     9.168915
# 16997      1244.0       456.0         3.0313            103600.0    10.057614
# 16998      1298.0       478.0         1.9797             85800.0    10.026465
# 16999       806.0       270.0         3.0147             94600.0     9.115597
#
#        dist_hospital
# 0           8.187319
# 1           7.966235
# 2           8.143077
# 3           8.154416
# 4           8.183508
# ...              ...
# 16995       4.233675
# 16996       4.332320
# 16997       5.358694
# 16998       5.322593
# 16999       4.249012
#
# [17000 rows x 11 columns]

# %%
# A house is "close" if near at least one (school OR hospital)
df_2["close_to_institution"] = (df_2["dist_school"] < 0.5) | (df_2["dist_hospital"] < 0.5)

close = df_2[df_2["close_to_institution"]]["median_house_value"]
far   = df_2[~df_2["close_to_institution"]]["median_house_value"]
far
# Out:
# 0         66900.0
# 1         80100.0
# 2         85700.0
# 3         73400.0
# 4         65500.0
#            ...
# 16995    111400.0
# 16996     79000.0
# 16997    103600.0
# 16998     85800.0
# 16999     94600.0
# Name: median_house_value, Length: 10171, dtype: float64
