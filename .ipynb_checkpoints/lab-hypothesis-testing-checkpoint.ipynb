# %% [markdown]
# # Lab | Hypothesis Testing

# %% [markdown]
# **Objective**
#
# Welcome to the Hypothesis Testing Lab, where we embark on an enlightening journey through the realm of statistical decision-making! In this laboratory, we delve into various scenarios, applying the powerful tools of hypothesis testing to scrutinize and interpret data.
#
# From testing the mean of a single sample (One Sample T-Test), to investigating differences between independent groups (Two Sample T-Test), and exploring relationships within dependent samples (Paired Sample T-Test), our exploration knows no bounds. Furthermore, we'll venture into the realm of Analysis of Variance (ANOVA), unraveling the complexities of comparing means across multiple groups.
#
# So, grab your statistical tools, prepare your hypotheses, and let's embark on this fascinating journey of exploration and discovery in the world of hypothesis testing!

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# In this challenge, we will be working with pokemon data. The data can be found here:
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv

# %%
#libraries
import pandas as pd
import scipy.stats as st
import numpy as np
import func as f

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv")
df
# Out:
#                Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0         Bulbasaur    Grass  Poison  45      49       49       65       65
# 1           Ivysaur    Grass  Poison  60      62       63       80       80
# 2          Venusaur    Grass  Poison  80      82       83      100      100
# 3     Mega Venusaur    Grass  Poison  80     100      123      122      120
# 4        Charmander     Fire     NaN  39      52       43       60       50
# ..              ...      ...     ...  ..     ...      ...      ...      ...
# 795         Diancie     Rock   Fairy  50     100      150      100      150
# 796    Mega Diancie     Rock   Fairy  50     160      110      160      110
# 797  Hoopa Confined  Psychic   Ghost  80     110       60      150      130
# 798   Hoopa Unbound  Psychic    Dark  80     160       60      170      130
# 799       Volcanion     Fire   Water  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# - We posit that Pokemons of type Dragon have, on average, more HP stats than Grass. Choose the propper test and, with 5% significance, comment your findings.

# %%
#code here
# H0: Pokemons of type Dragon on average =< HP stats than Grass
# H1: Pokemons of type Dragon on average > HP stats than Grass
# 5% significance -> alpha = 0.05
copy = f.columns_formating(df)
df = copy

# %%
dragon_sample = df[df["type_2"] == "Dragon"]["hp"]
dragon_sample.head(3)
# Out:
# 7      78
# 196    90
# 249    75
# Name: hp, dtype: int64

# %%
grass_sample = df[df["type_2"] == "Grass"]["hp"]
grass_sample.head(3)
# Out:
# 51      35
# 52      60
# 271    100
# Name: hp, dtype: int64

# %%
dragon_sample.describe()
# Out:
# count     18.000000
# mean      82.166667
# std       29.380366
# min       40.000000
# 25%       66.250000
# 50%       79.000000
# 75%       90.000000
# max      150.000000
# Name: hp, dtype: float64

# %%
grass_sample.describe()
# Out:
# count     25.000000
# mean      62.640000
# std       16.790076
# min       35.000000
# 25%       50.000000
# 50%       60.000000
# 75%       75.000000
# max      100.000000
# Name: hp, dtype: float64

# %% [markdown]
# **Test selection** We have two independant samples, that means we can use "Two Sample T-test" for solving this task

# %%
st.ttest_ind(dragon_sample, grass_sample, equal_var=False)
# Out:
# TtestResult(statistic=np.float64(2.537168832791051), pvalue=np.float64(0.017802230213627132), df=np.float64(24.957215454925205))

# %% [markdown]
# **Conclusion.**
# Because pvalue is lower than alpha = 0.05 (this is our 5% sugnificance level for this task), we reject the H0 hypothesis. H1 is true -> "Pokemons of type Dragon have, on average, more HP stats than Grass"

# %% [markdown]
# - We posit that Legendary Pokemons have different stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) when comparing with Non-Legendary. Choose the propper test and, with 5% significance, comment your findings.

# %%
df.head(1)
# Out:
#         name type_1  type_2  hp  attack  defense  sp_atk  sp_def  speed  \
# 0  Bulbasaur  Grass  Poison  45      49       49      65      65     45
#
#    generation  legendary
# 0           1      False

# %%
#code here
# H0 Legendary Pokemons stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) ==  Non-Legendary stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed)
# H1 Legendary Pokemons stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) !=  Non-Legendary stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed)
# 5% sugnificance level  -> alpha = 0.05

legendary_sample = df[df["legendary"] == True][["hp", "attack", "defense", "sp_atk", "sp_def", "speed"]]
legendary_sample.head(1)
# Out:
#      hp  attack  defense  sp_atk  sp_def  speed
# 156  90      85      100      95     125     85

# %%
non_legendary_sample = df[df["legendary"] == False][["hp", "attack", "defense", "sp_atk", "sp_def", "speed"]]
non_legendary_sample.head(1)
# Out:
#    hp  attack  defense  sp_atk  sp_def  speed
# 0  45      49       49      65      65     45

# %% [markdown]
# **Test selection** We have two independant groups in two samples, that means we can use "ANOVA" test for solving this task

# %%
f_st, p_v = st.f_oneway(legendary_sample, non_legendary_sample)
list_p = [np.format_float_positional(p, 5) for p in p_v]
list_p
# Out:
# ['0.00000', '0.00000', '0.00000', '0.00000', '0.00000', '0.00000']

# %%
legendary_sample.describe()
# Out:
#                hp      attack     defense      sp_atk      sp_def       speed
# count   65.000000   65.000000   65.000000   65.000000   65.000000   65.000000
# mean    92.738462  116.676923   99.661538  122.184615  105.938462  100.184615
# std     21.722164   30.348037   28.255131   31.104608   28.827004   22.952323
# min     50.000000   50.000000   20.000000   50.000000   20.000000   50.000000
# 25%     80.000000  100.000000   90.000000  100.000000   90.000000   90.000000
# 50%     91.000000  110.000000  100.000000  120.000000  100.000000  100.000000
# 75%    105.000000  131.000000  115.000000  150.000000  120.000000  110.000000
# max    150.000000  190.000000  200.000000  194.000000  200.000000  180.000000

# %%
non_legendary_sample.describe()
# Out:
#                hp      attack     defense      sp_atk      sp_def       speed
# count  735.000000  735.000000  735.000000  735.000000  735.000000  735.000000
# mean    67.182313   75.669388   71.559184   68.454422   68.892517   65.455782
# std     24.808849   30.490153   30.408194   29.091705   25.669310   27.843038
# min      1.000000    5.000000    5.000000   10.000000   20.000000    5.000000
# 25%     50.000000   54.500000   50.000000   45.000000   50.000000   45.000000
# 50%     65.000000   72.000000   66.000000   65.000000   65.000000   64.000000
# 75%     79.500000   95.000000   85.000000   85.000000   85.000000   85.000000
# max    255.000000  185.000000  230.000000  175.000000  230.000000  160.000000

# %% [markdown]
# **Conclusion 1.**
# - "ANOVA" test gives us pvalues sugnificanetly lower than alpha = 0.05. That means we can reject H0 hypothesis, whish sais that Legendary group has stats equal to Non-Legendary
# - H1 is true -> Legendary Pokemons stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) !=  Non-Legendary stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed)
# - We have different amount of rows in samples: legendary_sample (65 rows) smaller than non_legendary_sample (735 rows)
# - All mean values in legendary_sample are bigger than mean values in non_legendary_sample

# %% [markdown]
# **Challenge 2**

# %% [markdown]
# In this challenge, we will be working with california-housing data. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# **We posit that houses close to either a school or a hospital are more expensive.**
#
# - School coordinates (-118, 34)
# - Hospital coordinates (-122, 37)
#
# We consider a house (neighborhood) to be close to a school or hospital if the distance is lower than 0.50.
#
# Hint:
# - Write a function to calculate euclidean distance from each house (neighborhood) to the school and to the hospital.
# - Divide your dataset into houses close and far from either a hospital or school.
# - Choose the propper test and, with 5% significance, comment your findings.

# %%
df["coordinate"] = df[["longitude", "latitude"]].apply(tuple, axis=1)
df["coordinate"]
# Out:
# 0        (-114.31, 34.19)
# 1         (-114.47, 34.4)
# 2        (-114.56, 33.69)
# 3        (-114.57, 33.64)
# 4        (-114.57, 33.57)
#                ...
# 16995    (-124.26, 40.58)
# 16996    (-124.27, 40.69)
# 16997     (-124.3, 41.84)
# 16998      (-124.3, 41.8)
# 16999    (-124.35, 40.54)
# Name: coordinate, Length: 17000, dtype: object

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
np.cos(34)
# Out:
# np.float64(-0.8485702747846052)

# %%
df["longitude_dif_school"] = [abs(-118 - x)*111000*abs(np.cos(np.radians(y))) for x, y in df["coordinate"]]
df["longitude_dif_school"]
# Out:
# 0        338804.108878
# 1        323304.222030
# 2        317710.334015
# 3        316970.935410
# 4        317228.378974
#              ...
# 16995    527745.074990
# 16996    527717.956111
# 16997    520985.836080
# 16998    521311.366578
# 16999    535652.435085
# Name: longitude_dif_school, Length: 17000, dtype: float64

# %%
df["latitude_dif_school"] = [abs(34 - lat )*111000 for lat in df["latitude"]]
df["latitude_dif_school"]
# Out:
# 0         21090.0
# 1         44400.0
# 2         34410.0
# 3         39960.0
# 4         47730.0
#            ...
# 16995    730380.0
# 16996    742590.0
# 16997    870240.0
# 16998    865800.0
# 16999    725940.0
# Name: latitude_dif_school, Length: 17000, dtype: float64

# %%
df["distance_prep"] = df[["longitude_dif_school", "latitude_dif_school"]].apply(tuple, axis=1)
df["distance_prep"]
# Out:
# 0        (338804.10887841927, 21089.99999999975)
# 1        (323304.22203038447, 44399.99999999984)
# 2        (317710.3340146983, 34410.000000000255)
# 3         (316970.935409693, 39959.999999999935)
# 4        (317228.37897419505, 47729.99999999997)
#                           ...
# 16995     (527745.0749898482, 730379.9999999998)
# 16996     (527717.9561110897, 742589.9999999998)
# 16997     (520985.8360804931, 870240.0000000003)
# 16998    (521311.36657822534, 865799.9999999997)
# 16999     (535652.4350852804, 725939.9999999999)
# Name: distance_prep, Length: 17000, dtype: object

# %%
df["distance_school"] = [(x*x + y*y)**0.5 for x, y in df["distance_prep"]]
df["distance_school"]
# Out:
# 0        3.394599e+05
# 1        3.263388e+05
# 2        3.195683e+05
# 3        3.194799e+05
# 4        3.207990e+05
#              ...
# 16995    9.010937e+05
# 16996    9.110028e+05
# 16997    1.014270e+06
# 16998    1.010631e+06
# 16999    9.021709e+05
# Name: distance_school, Length: 17000, dtype: float64

# %%
df["longitude_dif_hospital"] = [abs(-122 - x)*111000*abs(np.cos(np.radians(y))) for x, y in df["coordinate"]]

# %%
df["latitude_dif_hospital"] = [abs(37 - lat_h )*111000 for lat_h in df["latitude"]]

# %%
df["distance_prep_hospital"] = df[["longitude_dif_school", "latitude_dif_school"]].apply(tuple, axis=1)

# %%
df["distance_hospital"] = [(x*x + y*y)**0.5 for x, y in df["distance_prep"]]

# %%
threshold = 0.50 * 111000

# %%
df["close_to_school"] = np.where(df["distance_school"] < threshold, True, False)
df["close_to_hospital"] = np.where(df["distance_school"] < threshold, True, False)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
close_to_school = df[df["close_to_school"] == True]["distance_school"]
far_from_school = df[df["close_to_school"] == False]["distance_school"]

# %%
close_to_hospital = df[df["close_to_hospital"] == True]["distance_hospital"]
far_from_hospital = df[df["close_to_hospital"] == False]["distance_hospital"]

# %%
close_to_school
# Out:
# 2226    55366.205213
# 2227    55213.902332
# 2228    55213.902332
# 2229    55333.685911
# 2230    55333.685911
#             ...
# 8711    54943.919222
# 8712    53341.402158
# 8731    54937.153935
# 8732    53749.916523
# 8760    55245.521514
# Name: distance_school, Length: 6088, dtype: float64

# %%
#H0 Houses in 'close_to_school' and 'close_to_hospital' are far from school and hospital
# H1 Houses in 'close_to_school' and 'close_to_hospital' are close to school and hospital
# alpha = 0.50

st.f_oneway(close_to_school, close_to_hospital)
# Out:
# F_onewayResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))

# %% [markdown]
# **Conclusion.** "ANOVA" test gives us pvalues more than alpha = 0.05. That means we can accept H0 and the sample group means are completely identical or that the between-group variance is zero
