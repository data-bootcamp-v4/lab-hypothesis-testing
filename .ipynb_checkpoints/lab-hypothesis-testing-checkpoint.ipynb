# %% [markdown]
# # Lab | Hypothesis Testing

# %% [markdown]
# **Objective**
#
# Welcome to the Hypothesis Testing Lab, where we embark on an enlightening journey through the realm of statistical decision-making! In this laboratory, we delve into various scenarios, applying the powerful tools of hypothesis testing to scrutinize and interpret data.
#
# From testing the mean of a single sample (One Sample T-Test), to investigating differences between independent groups (Two Sample T-Test), and exploring relationships within dependent samples (Paired Sample T-Test), our exploration knows no bounds. Furthermore, we'll venture into the realm of Analysis of Variance (ANOVA), unraveling the complexities of comparing means across multiple groups.
#
# So, grab your statistical tools, prepare your hypotheses, and let's embark on this fascinating journey of exploration and discovery in the world of hypothesis testing!

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# In this challenge, we will be working with pokemon data. The data can be found here:
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv

# %%
#libraries
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv")
df.head(20)
# Out:
#                 Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0          Bulbasaur  Grass  Poison  45      49       49       65       65
# 1            Ivysaur  Grass  Poison  60      62       63       80       80
# 2           Venusaur  Grass  Poison  80      82       83      100      100
# 3      Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4         Charmander   Fire     NaN  39      52       43       60       50
# 5         Charmeleon   Fire     NaN  58      64       58       80       65
# 6          Charizard   Fire  Flying  78      84       78      109       85
# 7   Mega Charizard X   Fire  Dragon  78     130      111      130       85
# 8   Mega Charizard Y   Fire  Flying  78     104       78      159      115
# 9           Squirtle  Water     NaN  44      48       65       50       64
# 10         Wartortle  Water     NaN  59      63       80       65       80
# ...

# %% [markdown]
# - We posit that Pokemons of type Dragon have, on average, more HP stats than Grass. Choose the propper test and, with 5% significance, comment your findings.

# %%
#code here
display(df["Type 1"].unique())
display(df["Type 2"].unique())
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
# Determine if there is a combination of both Dragon and Grass in Type 1 or Type 2

# Count how many rows have Dragon in Type 1 or Type 2
dragon_count = ((df["Type 1"] == "Dragon") | (df["Type 2"] == "Dragon")).sum()

# Count how many rows have Grass in Type 1 or Type 2
grass_count = ((df["Type 1"] == "Grass") | (df["Type 2"] == "Grass")).sum()

# Count how many rows have both Dragon and Grass in Type 1 and Type 2
dragon_grass_count = ((df["Type 1"] == "Dragon") & (df["Type 2"] == "Grass")) | ((df["Type 1"] == "Grass") & (df["Type 2"] == "Dragon"))

# Total count of Dragon and Grass combinations
dragon_grass_combination_count = dragon_grass_count.sum()

# Print out the counts
print("Rows with Dragon in Type 1 or Type 2:", dragon_count)
print("Rows with Grass in Type 1 or Type 2:", grass_count)
print("Rows with both Dragon and Grass (in any combination of columns):", dragon_grass_combination_count)
# Out:
# Rows with Dragon in Type 1 or Type 2: 50
# Rows with Grass in Type 1 or Type 2: 95
# Rows with both Dragon and Grass (in any combination of columns): 1

# %%
# Remove the row where Type 1 is "Dragon" and Type 2 is "Grass" (or vice versa)
df_cleaned = df[~((df["Type 1"] == "Dragon") & (df["Type 2"] == "Grass")) & ~((df["Type 1"] == "Grass") & (df["Type 2"] == "Dragon"))]

# Print the cleaned dataframe
print(df_cleaned)
# Out:
#                Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0         Bulbasaur    Grass  Poison  45      49       49       65       65
# 1           Ivysaur    Grass  Poison  60      62       63       80       80
# 2          Venusaur    Grass  Poison  80      82       83      100      100
# 3     Mega Venusaur    Grass  Poison  80     100      123      122      120
# 4        Charmander     Fire     NaN  39      52       43       60       50
# ..              ...      ...     ...  ..     ...      ...      ...      ...
# 795         Diancie     Rock   Fairy  50     100      150      100      150
# 796    Mega Diancie     Rock   Fairy  50     160      110      160      110
# 797  Hoopa Confined  Psychic   Ghost  80     110       60      150      130
# 798   Hoopa Unbound  Psychic    Dark  80     160       60      170      130
# 799       Volcanion     Fire   Water  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %%
# Create boolean columns for Dragon and Grass types based on Type 1 or Type 2
df_cleaned.loc[:, "Is_Dragon"] = (df_cleaned["Type 1"] == "Dragon") | (df_cleaned["Type 2"] == "Dragon")
df_cleaned.loc[:, "Is_Grass"] = (df_cleaned["Type 1"] == "Grass") | (df_cleaned["Type 2"] == "Grass")

# Extract Dragon-type and Grass-type Pokémon
dragon_pokemon = df_cleaned[df_cleaned["Is_Dragon"]]
grass_pokemon = df_cleaned[df_cleaned["Is_Grass"]]

# Perform the two-sample t-test on the 'HP' stat instead of 'Attack'
t_stat_hp, p_value_hp = stats.ttest_ind(dragon_pokemon["HP"], grass_pokemon["HP"])

# Print the result for HP
print(f"T-statistic (HP): {t_stat_hp}")
print(f"P-value (HP): {p_value_hp}")


# Based on the HP statistic and the t-test result, Dragon-type Pokémon have, 
# on average, more HP than Grass-type Pokémon.

# The difference is statistically significant (p-value << 0.05), so this is 
# a real difference, not just due to random chance.
# Out:
# T-statistic (HP): 4.516630348350027
# P-value (HP): 1.3167963652321234e-05

# %% [markdown]
# - We posit that Legendary Pokemons have different stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) when comparing with Non-Legendary. Choose the propper test and, with 5% significance, comment your findings.

# %%
import pandas as pd
from scipy.stats import ttest_ind

# Load dataset
url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv"
df = pd.read_csv(url)

# Separate Legendary and Non-Legendary Pokémon
legendary = df[df['Legendary'] == True]
non_legendary = df[df['Legendary'] == False]

# Stats to test
stats = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

# Print header
print("Stat\t\tp-value (decimal)     p-value (sci)     Significant?")
print("-" * 70)

# Perform t-tests
for stat in stats:
    stat_legend = legendary[stat]
    stat_nonlegend = non_legendary[stat]
    t_stat, p_value = ttest_ind(stat_legend, stat_nonlegend)
    significance = "Yes" if p_value < 0.05 else "No"

    print(f"{stat:<10}\t{p_value:.15f}     {p_value:.2e}         {significance}")


# Based on the p-values, we can say that Legendary Pokémon have different stats compared to Non-Legendary Pokémon.
# The differences are statistically significant (p-values << 0.05), meaning they are real and not just random chance.
# Therefore, we accept the hypothesis that Legendary Pokémon have different base stats from Non-Legendary Pokémon.
# Out:
# Stat		p-value (decimal)     p-value (sci)     Significant?
# ----------------------------------------------------------------------
# HP        	0.000000000000003     3.33e-15         Yes
# Attack    	0.000000000000000     7.83e-24         Yes
# Defense   	0.000000000001584     1.58e-12         Yes
# Sp. Atk   	0.000000000000000     6.31e-41         Yes
# Sp. Def   	0.000000000000000     1.84e-26         Yes
# Speed     	0.000000000000000     2.35e-21         Yes

# %% [markdown]
# **Challenge 2**

# %% [markdown]
# In this challenge, we will be working with california-housing data. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# **We posit that houses close to either a school or a hospital are more expensive.**
#
# - School coordinates (-118, 34)
# - Hospital coordinates (-122, 37)
#
# We consider a house (neighborhood) to be close to a school or hospital if the distance is lower than 0.50.
#
# Hint:
# - Write a function to calculate euclidean distance from each house (neighborhood) to the school and to the hospital.
# - Divide your dataset into houses close and far from either a hospital or school.
# - Choose the propper test and, with 5% significance, comment your findings.
