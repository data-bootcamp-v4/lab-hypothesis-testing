# %% [markdown]
# # Lab | Hypothesis Testing

# %% [markdown]
# **Objective**
#
# Welcome to the Hypothesis Testing Lab, where we embark on an enlightening journey through the realm of statistical decision-making! In this laboratory, we delve into various scenarios, applying the powerful tools of hypothesis testing to scrutinize and interpret data.
#
# From testing the mean of a single sample (One Sample T-Test), to investigating differences between independent groups (Two Sample T-Test), and exploring relationships within dependent samples (Paired Sample T-Test), our exploration knows no bounds. Furthermore, we'll venture into the realm of Analysis of Variance (ANOVA), unraveling the complexities of comparing means across multiple groups.
#
# So, grab your statistical tools, prepare your hypotheses, and let's embark on this fascinating journey of exploration and discovery in the world of hypothesis testing!

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# In this challenge, we will be working with pokemon data. The data can be found here:
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv

# %%
#libraries
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv")
df

# %% [markdown]
# - We posit that Pokemons of type Dragon have, on average, more HP stats than Grass. Choose the propper test and, with 5% significance, comment your findings.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
df_dragon = df[(df["Type 1"] == "Dragon") | (df["Type 2"] == "Dragon")]["HP"]
df_grass  = df[(df["Type 1"] == "Grass")  | (df["Type 2"] == "Grass")]["HP"]

# %%
df_grass

# %%
#code 
# Ho: the mean of df_dragon ≤ mean of df_grass
# H1: the mean of df_dragon > mean of df_grass
#with alpha = 0.05
# I will use oneside t-test
st.ttest_ind(df_dragon, df_grass, equal_var=False, alternative="greater")
# the "p-value" is too small so we reject the null hypothesis.
# We accept the H1 which means that the average of HP of the pokemon dragon is higher than the average of HP of the grass.

# %% [markdown]
# - We posit that Legendary Pokemons have different stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) when comparing with Non-Legendary. Choose the propper test and, with 5% significance, comment your findings.

# %%
df.info()

# %%
#code here
## H₀: Legendary and Non-Legendary Pokémon have the same average HP (μ₁ = μ₂)
## H₁: Legendary and Non-Legendary Pokémon have different average HP (μ₁ ≠ μ₂)
## Alph: 0.05
#st.ttest_ind(average_hp_legendary, average_hp_non_legendary, equal_var=False, alternative="two-sided")
import scipy.stats as st

# Calculate average HP (already correct)
average_hp_legendary = df[df["Legendary"] == True]["HP"].mean()
average_hp_non_legendary = df[df["Legendary"] == False]["HP"].mean()

# Get HP data, dropping NaNs just in case
legendary_hp = df[df["Legendary"] == True]["HP"].dropna()
non_legendary_hp = df[df["Legendary"] == False]["HP"].dropna()

# Perform two-sided Welch's t-test
t_stat, p_value = st.ttest_ind(
    legendary_hp,
    non_legendary_hp,
    equal_var=False,
    alternative="two-sided"
)

# Print results
print("Average HP - Legendary:", average_hp_legendary)
print("Average HP - Non-Legendary:", average_hp_non_legendary)
print("t-statistic:", t_stat)
print("p-value:", p_value)
## The p-value is very small the the H0 is rejected so the H1 is accepted which means that there is a differnce

# %%
#code here
## H₀: Legendary and Non-Legendary Pokémon have the same average Attack (μ₁ = μ₂)
## H₁: Legendary and Non-Legendary Pokémon have different average Attack (μ₁ ≠ μ₂)
## Alph: 0.05
import scipy.stats as st

# Calculate average Attack (already correct)
average_Attack_legendary = df[df["Legendary"] == True]["Attack"].mean()
average_Attack_non_legendary = df[df["Legendary"] == False]["Attack"].mean()

# Get Attack data, dropping NaNs just in case
legendary_Attack = df[df["Legendary"] == True]["Attack"].dropna()
non_legendary_Attack = df[df["Legendary"] == False]["Attack"].dropna()

# Perform two-sided Welch's t-test
t_stat, p_value = st.ttest_ind(
    legendary_Attack,
    non_legendary_Attack,
    equal_var=False,
    alternative="two-sided"
)

# Print results
print("Average Attack - Legendary:", average_Attack_legendary)
print("Average Attack - Non-Legendary:", average_Attack_non_legendary)
print("t-statistic:", t_stat)
print("p-value:", p_value)
## The p-value is very small the the H0 is rejected so the H1 is accepted which means that there is a differnce

# %%
#code here
## H₀: Legendary and Non-Legendary Pokémon have the same average Defense (μ₁ = μ₂)
## H₁: Legendary and Non-Legendary Pokémon have different average Defense (μ₁ ≠ μ₂)
## Alph: 0.05
import scipy.stats as st

# Calculate average Defense (already correct)
average_Defense_legendary = df[df["Legendary"] == True]["Defense"].mean()
average_Defense_non_legendary = df[df["Legendary"] == False]["Defense"].mean()

# Get Defense data, dropping NaNs just in case
legendary_Defense = df[df["Legendary"] == True]["Defense"].dropna()
non_legendary_Defense = df[df["Legendary"] == False]["Defense"].dropna()

# Perform two-sided Welch's t-test
t_stat, p_value = st.ttest_ind(
    legendary_Defense,
    non_legendary_Defense,
    equal_var=False,
    alternative="two-sided"
)

# Print results
print("Average Defense - Legendary:", average_Defense_legendary)
print("Average Defense - Non-Legendary:", average_Defense_non_legendary)
print("t-statistic:", t_stat)
print("p-value:", p_value)
## The p-value is very small the the H0 is rejected so the H1 is accepted which means that there is a differnce

# %%
#code here
## H₀: Legendary and Non-Legendary Pokémon have the same average Sp.Atk (μ₁ = μ₂)
## H₁: Legendary and Non-Legendary Pokémon have different average Sp.Atk (μ₁ ≠ μ₂)
## Alph: 0.05
import scipy.stats as st

# Calculate average Defense (already correct)
average_Sp_Atk_legendary = df[df["Legendary"] == True]["Sp. Atk"].mean()
average_Sp_Atk_non_legendary = df[df["Legendary"] == False]["Sp. Atk"].mean()

# Get Defense data, dropping NaNs just in case
legendary_Sp_Atk = df[df["Legendary"] == True]["Sp. Atk"].dropna()
non_legendary_Sp_Atk = df[df["Legendary"] == False]["Sp. Atk"].dropna()

# Perform two-sided Welch's t-test
t_stat, p_value = st.ttest_ind(
    legendary_Sp_Atk,
    non_legendary_Sp_Atk,
    equal_var=False,
    alternative="two-sided"
)

# Print results
print("Average Sp.Atk - Legendary:", average_Sp_Atk_legendary)
print("Average Sp.Atk - Non-Legendary:", average_Sp_Atk_non_legendary)
print("t-statistic:", t_stat)
print("p-value:", p_value)
## The p-value is very small the the H0 is rejected so the H1 is accepted which means that there is a differnce

# %%
#code here
## H₀: Legendary and Non-Legendary Pokémon have the same average Sp. Def (μ₁ = μ₂)
## H₁: Legendary and Non-Legendary Pokémon have different average Sp. Def (μ₁ ≠ μ₂)
## Alph: 0.05
import scipy.stats as st

# Calculate average Sp. Def (already correct)
average_Sp_Atk_legendary = df[df["Legendary"] == True]["Sp. Def"].mean()
average_Sp_Atk_non_legendary = df[df["Legendary"] == False]["Sp. Def"].mean()

# Get Defense data, dropping NaNs just in case
legendary_Sp_Def = df[df["Legendary"] == True]["Sp. Def"].dropna()
non_legendary_Sp_Def = df[df["Legendary"] == False]["Sp. Def"].dropna()

# Perform two-sided Welch's t-test
t_stat, p_value = st.ttest_ind(
    legendary_Sp_Def,
    non_legendary_Sp_Def,
    equal_var=False,
    alternative="two-sided"
)

# Print results
print("Average Sp.Atk - Legendary:", average_Sp_Atk_legendary)
print("Average Sp.Atk - Non-Legendary:", average_Sp_Atk_non_legendary)
print("t-statistic:", t_stat)
print("p-value:", p_value)
## The p-value is very small the the H0 is rejected so the H1 is accepted which means that there is a differnce

# %%
#code here
## H₀: Legendary and Non-Legendary Pokémon have the same average Speed (μ₁ = μ₂)
## H₁: Legendary and Non-Legendary Pokémon have different average Speed (μ₁ ≠ μ₂)
## Alph: 0.05
import scipy.stats as st

# Calculate average Sp. Def (already correct)
average_Speed_legendary = df[df["Legendary"] == True]["Speed"].mean()
average_Speed_non_legendary = df[df["Legendary"] == False]["Speed"].mean()

# Get Defense data, dropping NaNs just in case
legendary_Speed = df[df["Legendary"] == True]["Speed"].dropna()
non_legendary_Speed = df[df["Legendary"] == False]["Speed"].dropna()

# Perform two-sided Welch's t-test
t_stat, p_value = st.ttest_ind(
    legendary_Speed,
    non_legendary_Speed,
    equal_var=False,
    alternative="two-sided"
)

# Print results
print("Average Sp.Atk - Legendary:", average_Speed_legendary)
print("Average Sp.Atk - Non-Legendary:", average_Speed_non_legendary)
print("t-statistic:", t_stat)
print("p-value:", p_value)
## The p-value is very small the the H0 is rejected so the H1 is accepted which means that there is a differnce

# %% [markdown]
# **Challenge 2**

# %% [markdown]
# In this challenge, we will be working with california-housing data. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv")
df.head()

# %% [markdown]
# **We posit that houses close to either a school or a hospital are more expensive.**
#
# - School coordinates (-118, 34)
# - Hospital coordinates (-122, 37)
#
# We consider a house (neighborhood) to be close to a school or hospital if the distance is lower than 0.50.
#
# Hint:
# - Write a function to calculate euclidean distance from each house (neighborhood) to the school and to the hospital.
# - Divide your dataset into houses close and far from either a hospital or school.
# - Choose the propper test and, with 5% significance, comment your findings.

# %%
# Coordinates
import numpy as np

school_coords = (-118, 34)
hospital_coords = (-122, 37)

# Function to calculate Euclidean distance
def euclidean_distance(lon1, lat1, lon2, lat2):
    return np.sqrt((lon1 - lon2)**2 + (lat1 - lat2)**2)

# Calculate distances
df['dist_to_school'] = df.apply(lambda row: euclidean_distance(row['longitude'], row['latitude'], *school_coords), axis=1)
df['dist_to_hospital'] = df.apply(lambda row: euclidean_distance(row['longitude'], row['latitude'], *hospital_coords), axis=1)

# Determine if a house is close to a school or hospital
df['is_close'] = (df['dist_to_school'] < 0.5) | (df['dist_to_hospital'] < 0.5)

# Optional: check correlation or price comparison
# print(df[df['is_close'] == True]['price'].mean())
# print(df[df['is_close'] == False]['price'].mean())

# %%
df.info()

# %%
df["is_close"].value_counts()

# %%
# check correlation or price comparison
print(df[df['is_close'] == True]['median_house_value'].mean())
print(df[df['is_close'] == False]['median_house_value'].mean())

# %%
# Group A: Houses close to school or hospital (is_close == True)
# Group B: Houses not close (is_close == False)

# Null Hypothesis (H₀): There is no difference in average house price between the two groups
# 𝜇 𝐴 = 𝜇 𝐵

# Alternative Hypothesis (H₁): Houses close to school or hospital have higher average prices
# 𝜇 𝐴 > 𝜇 𝐵
# Alpha =0.05, one tail test

# %%
from scipy.stats import ttest_ind

# Separate prices into two groups
close_prices = df[df['is_close'] == True]['median_house_value']
not_close_prices = df[df['is_close'] == False]['median_house_value']

# Perform one-tailed t-test
t_stat, p_value = ttest_ind(close_prices, not_close_prices, equal_var=False)

# Since it's a one-tailed test (greater), divide p-value by 2
p_value_one_tailed = p_value / 2

# Print results
print(f"T-statistic: {t_stat:.3f}")
print(f"One-tailed p-value: {p_value_one_tailed:.4f}")

# Check significance
alpha = 0.05
if p_value_one_tailed < alpha and t_stat > 0:
    print("✅ We reject the null hypothesis: Houses close to a school or hospital are significantly more expensive.")
else:
    print("❌ We fail to reject the null hypothesis: No significant evidence that close houses are more expensive.")
