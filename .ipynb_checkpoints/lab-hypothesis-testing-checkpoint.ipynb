# %% [markdown]
# # Lab | Hypothesis Testing

# %% [markdown]
# **Objective**
#
# Welcome to the Hypothesis Testing Lab, where we embark on an enlightening journey through the realm of statistical decision-making! In this laboratory, we delve into various scenarios, applying the powerful tools of hypothesis testing to scrutinize and interpret data.
#
# From testing the mean of a single sample (One Sample T-Test), to investigating differences between independent groups (Two Sample T-Test), and exploring relationships within dependent samples (Paired Sample T-Test), our exploration knows no bounds. Furthermore, we'll venture into the realm of Analysis of Variance (ANOVA), unraveling the complexities of comparing means across multiple groups.
#
# So, grab your statistical tools, prepare your hypotheses, and let's embark on this fascinating journey of exploration and discovery in the world of hypothesis testing!

# %% [markdown]
# ## **Challenge 1 - Pokemon**

# %% [markdown]
# In this challenge, we will be working with pokemon data. The data can be found here:
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv

# %%
#libraries
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy import stats

# %%
df_poke = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv")
df_poke
# Out:
#                Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0         Bulbasaur    Grass  Poison  45      49       49       65       65
# 1           Ivysaur    Grass  Poison  60      62       63       80       80
# 2          Venusaur    Grass  Poison  80      82       83      100      100
# 3     Mega Venusaur    Grass  Poison  80     100      123      122      120
# 4        Charmander     Fire     NaN  39      52       43       60       50
# ..              ...      ...     ...  ..     ...      ...      ...      ...
# 795         Diancie     Rock   Fairy  50     100      150      100      150
# 796    Mega Diancie     Rock   Fairy  50     160      110      160      110
# 797  Hoopa Confined  Psychic   Ghost  80     110       60      150      130
# 798   Hoopa Unbound  Psychic    Dark  80     160       60      170      130
# 799       Volcanion     Fire   Water  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %%
df_poke.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        799 non-null    str
#  1   Type 1      800 non-null    str
#  2   Type 2      414 non-null    str
#  3   HP          800 non-null    int64
#  4   Attack      800 non-null    int64
#  5   Defense     800 non-null    int64
#  6   Sp. Atk     800 non-null    int64
#  7   Sp. Def     800 non-null    int64
#  8   Speed       800 non-null    int64
#  9   Generation  800 non-null    int64
#  10  Legendary   800 non-null    bool
# dtypes: bool(1), int64(7), str(3)
# memory usage: 63.4 KB

# %% [markdown]
# ### - We posit that Pokemons of type Dragon have, on average, more HP stats than Grass. Choose the propper test and, with 5% significance, comment your findings.

# %% [markdown]
# #### Formulate hypothesis:

# %% [raw]
# Hypothesis
# WRONG:
# H0 HP-AVG(Dragon) >= HP-AVG(Grass) => ERROR don't use average because p_value(st.ttest_ind(df1, df2) or st.ttest_rel(df1, df2)needs the values, not the mean!!!
# H1 HP-AVG(Dragon) < HP-AVG(Grass) => ERROR don't use average because p_value(st.ttest_ind(df1, df2) or st.ttest_rel(df1, df2)needs the values, not the mean!!!
#
# CORRECT:
# H0 HP(Dragon) >= HP(Grass)
# H1 HP(Dragon) < HP(Grass)
#
# #significance level = 0.05

# %% [markdown]
# ####  Analyse data:

# %%
df_poke['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
len(df_poke['Type 1'].value_counts())
# Out:
# 18

# %%
len(df_poke['Type 2'].value_counts())
# Out:
# 18

# %%
set(df_poke['Type 1'].dropna()) == set(df_poke['Type 2'].dropna())
# Out:
# True

# %% [raw]
# Conclusion: 'Type 1' and 'Type 2' have the same values

# %% [markdown]
# #### Collect/Calculate data:

# %%
# avg dragon:
dragon_hp = df_poke[(df_poke['Type 1']=='Dragon') | (df_poke['Type 2']=='Dragon')]['HP']

#avg grass:
grass_hp = df_poke[(df_poke['Type 1']=='Grass') | (df_poke['Type 2']=='Grass')]['HP']

# %%
dragon_hp.head(2)
# Out:
# 7      78
# 159    41
# Name: HP, dtype: int64

# %%
grass_hp.head(2)
# Out:
# 0    45
# 1    60
# Name: HP, dtype: int64

# %% [markdown]
# #### Python way: (Includes - Calculate Test Statistic - Determine pi value - Decision making)

# %% [raw]
# Determine to use the appropriate:
# - Related st.ttest_rel(df1, df2)
# - Indepentdent st.ttest_ind(df1, df2)

# %%
result = st.ttest_ind(dragon_hp, grass_hp)
p_value = result.pvalue
p_value
# Out:
# np.float64(1.4019427478617656e-05)

# %%
# H0 HP-AVG(Dragon) >= HP-AVG(Grass)
# H1 HP-AVG(Dragon) < HP-AVG(Grass)

alpha = 0.05


if p_value > alpha:
    print("We are not able to reject the null hypothesis")
else:
    print("We reject the null hypothesis")
# Out:
# We reject the null hypothesis

# %% [markdown]
# 0.000014 < 0.05
#
# **This indicates there is statistically significant evidence that the mean HP of Dragon Pokémon differs from the mean HP of Grass Pokémon.**

# %% [markdown]
# ### - We posit that Legendary Pokemons have different stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) when comparing with Non-Legendary. Choose the propper test and, with 5% significance, comment your findings.

# %% [markdown]
# #### Formulate hypothesis:

# %% [raw]
# Since there are only two independent groups (legendary vs non_legendary), the appropriate test is a two-sample t-test (scipy.stats.ttest_ind), not a one-way ANOVA (f_oneway).
#
# ANOVA (f_oneway) is typically used when comparing three or more groups. (With exactly two groups, ANOVA and the t-test are mathematically equivalent, but the t-test is the standard choice.)

# %% [raw]
# H0: μLegendary HP = μNon-Legendary HP
# H1: μLegendary HP != μNon-Legendary HP
#
# H0: μLegendary Attack = μNon-Legendary Attack
# H1: μLegendary Attack != μNon-Legendary Attack
#
# H0: μLegendary Defense = μNon-Legendary Defense
# H1: μLegendary Defense != μNon-Legendary Defense
#
# H0: μLegendary SpAtk =μNon-Legendary SpAtk
# H1: μLegendary SpAtk !=μNon-Legendary SpAtk
#
# H0: μLegendary SpDef = μNon-Legendary SpDef
# H1: μLegendary SpDef != μNon-Legendary SpDef
#
# H0: μLegendary Speed = μNon-Legendary Speed
# H1: μLegendary Speed != μNon-Legendary Speed

# %% [markdown]
# ####  Analyse data:

# %%
df_poke.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        799 non-null    str
#  1   Type 1      800 non-null    str
#  2   Type 2      414 non-null    str
#  3   HP          800 non-null    int64
#  4   Attack      800 non-null    int64
#  5   Defense     800 non-null    int64
#  6   Sp. Atk     800 non-null    int64
#  7   Sp. Def     800 non-null    int64
#  8   Speed       800 non-null    int64
#  9   Generation  800 non-null    int64
#  10  Legendary   800 non-null    bool
# dtypes: bool(1), int64(7), str(3)
# memory usage: 63.4 KB

# %% [markdown]
# #### Collect/Calculate data:

# %%
legendary = df_poke[df_poke['Legendary']==True]
legendary
# Out:
#                Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 156        Articuno       Ice    Flying   90      85      100       95
# 157          Zapdos  Electric    Flying   90      90       85      125
# 158         Moltres      Fire    Flying   90     100       90      125
# 162          Mewtwo   Psychic       NaN  106     110       90      154
# 163   Mega Mewtwo X   Psychic  Fighting  106     190      100      154
# ..              ...       ...       ...  ...     ...      ...      ...
# 795         Diancie      Rock     Fairy   50     100      150      100
# 796    Mega Diancie      Rock     Fairy   50     160      110      160
# 797  Hoopa Confined   Psychic     Ghost   80     110       60      150
# 798   Hoopa Unbound   Psychic      Dark   80     160       60      170
# 799       Volcanion      Fire     Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 156      125     85           1       True
# ...

# %%
non_legendary = df_poke[df_poke['Legendary']==False]
non_legendary
# Out:
#                      Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0               Bulbasaur   Grass  Poison  45      49       49       65
# 1                 Ivysaur   Grass  Poison  60      62       63       80
# 2                Venusaur   Grass  Poison  80      82       83      100
# 3           Mega Venusaur   Grass  Poison  80     100      123      122
# 4              Charmander    Fire     NaN  39      52       43       60
# ..                    ...     ...     ...  ..     ...      ...      ...
# 787  Gourgeist Super Size   Ghost   Grass  85     100      122       58
# 788              Bergmite     Ice     NaN  55      69       85       32
# 789               Avalugg     Ice     NaN  95     117      184       44
# 790                Noibat  Flying  Dragon  40      30       35       45
# 791               Noivern  Flying  Dragon  85      70       80       97
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
Necesary series:

legendary_HP
non_legendary_HP

legendary_Attack
non_legendary_Attack

legendary_Defense
non_legendary_Defense

legendary_SpAtk
non_legendary_SpAtk

legendary_SpDef
non_legendary_SpDef

legendary_Speed
non_legendary_Speed

# %% [markdown]
# #### Python way: (Includes - Calculate Test Statistic - Determine pi value - Decision making)

# %% [raw]
# For this case, series and python way are done in the same loop

# %%
stats_cols = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

for col in stats_cols:
    legendary = df_poke[df_poke['Legendary']][col]
    nonlegendary = df_poke[~df_poke['Legendary']][col]

    result = stats.ttest_ind(legendary, nonlegendary, equal_var=False)

    print(f"{col}:")
    print(f"  t = {result.statistic:.3f}")
    print(f"  p = {result.pvalue:.4f}")

    if result.pvalue < 0.05:
        print("  Reject H₀: the means differ.\n")
    else:
        print("  Fail to reject H₀: no significant difference.\n")
# Out:
# HP:
#   t = 8.981
#   p = 0.0000
#   Reject H₀: the means differ.
#
# Attack:
#   t = 10.438
#   p = 0.0000
#   Reject H₀: the means differ.
#
# Defense:
#   t = 7.637
#   p = 0.0000
#   Reject H₀: the means differ.
#
# Sp. Atk:
#   t = 13.417
#   p = 0.0000
#   Reject H₀: the means differ.
#
# Sp. Def:
#   t = 10.016
#   p = 0.0000
#   Reject H₀: the means differ.
#
# Speed:
#   t = 11.475
#   p = 0.0000
#   Reject H₀: the means differ.

# %% [raw]
# the :.3f and :.4f are formatting instructions for the f-string.
#
# They control how many decimal places are displayed.
#
# :.3f
# f means fixed-point notation (normal decimal format)
# .3 means show 3 digits after the decimal point

# %% [markdown]
# Because you're performing six separate hypothesis tests, there's an increased chance of a false positive (Type I error). In many statistical analyses, it's appropriate to adjust for multiple comparisons (for example, using a Bonferroni correction, which would use a significance level of 0.05/6≈0.0083). Whether you should do this depends on the expectations of your course or assignment. If the exercise doesn't mention multiple-testing correction, using a 5% significance level for each test is usually acceptable.

# %% [markdown]
# ## **Challenge 2 - Housing**

# %% [markdown]
# In this challenge, we will be working with california-housing data. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv

# %%
df_housing = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv")
df_housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df_housing.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %% [markdown]
# ### **- We posit that houses close to either a school or a hospital are more expensive.**
#
# - School coordinates (-118, 34)
# - Hospital coordinates (-122, 37)
#
# We consider a house (neighborhood) to be close to a school or hospital if the distance is lower than 0.50.
#
# Hint:
# - Write a function to calculate euclidean distance from each house (neighborhood) to the school and to the hospital.
# - Divide your dataset into houses close and far from either a hospital or school.
# - Choose the propper test and, with 5% significance, comment your findings.

# %% [markdown]
# #### Formulate hypothesis:

# %% [markdown]
# **Step 5 — Choose the correct statistical test**

# %% [markdown]
# You are comparing:
#
# - Median house value of houses close to facilities
# - Median house value of houses far from facilities
#
# These are two independent groups, and the variable (median_house_value) is continuous.
#
# The correct test is:
# **Independent two-sample t-test**

# %% [raw]
# Hypotheses:
# H0 :μclose  = μfar
# H1 :μclose != μfar

# %% [markdown]
# **Step 1 — Understand the variables**
#
# longitude → x-coordinate
#
# latitude → y-coordinate
#
# median_house_value → the variable we want to compare

# %%
school = (-118, 34)
hospital = (-122, 37)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# ####  Analyse data:

# %% [markdown]
# #### Collect/Calculate data:

# %% [markdown]
# **Step 2 — Write a function for Euclidean distance**

# %%
def euclidean_distance(longitude, latitude, location):
    x2, y2 = location
    return np.sqrt((longitude - x2)**2 + (latitude - y2)**2)

# %%
euclidean_distance(-118.2, 34.1, school)
# Out:
# np.float64(0.22360679774998216)

# %% [markdown]
# **Step 3 — Calculate distances for every house**

# %% [markdown]
# Add column of distance of each house to the school

# %%
df_housing['distance_school'] = df_housing.apply(
    lambda row: euclidean_distance(
        row['longitude'],
        row['latitude'],
        school
    ),
    axis=1
)

# %% [markdown]
# Add column of distance of each house to the hospital

# %%
df_housing['distance_hospital'] = df_housing.apply(
    lambda row: euclidean_distance(
        row['longitude'],
        row['latitude'],
        hospital
    ),
    axis=1
)

# %%
df_housing[['distance_school', 'distance_hospital']].head()
# Out:
#    distance_school  distance_hospital
# 0         3.694888           8.187319
# 1         3.552591           7.966235
# 2         3.453940           8.143077
# 3         3.448840           8.154416
# 4         3.456848           8.183508

# %%
df_housing['distance_school'].mean()
# Out:
# np.float64(2.7179074203231233)

# %%
df_housing['distance_hospital'].mean()
# Out:
# np.float64(3.5095531351008202)

# %% [markdown]
# **Step 4 — Categorize close/far groups**

# %% [markdown]
# _Proposed premise:_  <br>
# A house is close if: _close to school_ OR _close to hospital_

# %%
#createa boolean mask

close = (
    (df_housing['distance_school'] < 0.50) | (df_housing['distance_hospital'] < 0.50)
)

# This does not create a new DataFrame.
# It creates a Series of True and False values, one for each row.

# %% [markdown]
# Why are we using the 0.5 closeness definition? <br>
# _Thresholds often come from business rules, scientific definitions, or domain knowledge, rather than being derived from the dataset itself._

# %%
#Create two datasets from the original:
houses_close = df_housing[close]

houses_far = df_housing[~close]

# The ~ operator means NOT.

# %%
print(len(houses_close))
print(len(houses_far))
# Out:
# 6829
# 10171

# %% [markdown]
# **Step 6 — Run the test**

# %%
# create the series of median house value for each group: for close and for far
close_values = houses_close['median_house_value']
far_values = houses_far['median_house_value']

# %% [markdown]
# #### Python way: (Includes - Calculate Test Statistic - Determine pi value - Decision making)

# %%
# Run Welch's t-test:
result = stats.ttest_ind(
    close_values,
    far_values,
    equal_var=False
)

print(result)
# Out:
# TtestResult(statistic=np.float64(37.992330214201516), pvalue=np.float64(3.0064957768591797e-301), df=np.float64(14571.229910954282))

# %% [markdown]
# **Step 7 — Interpret the result**

# %%
result.pvalue
# Out:
# np.float64(3.0064957768591797e-301)

# %%
alpha = 0.05

if result.pvalue < alpha:
    print("Reject H0: houses close to facilities have different prices.")
else:
    print("Fail to reject H0: no significant difference found.")
# Out:
# Reject H0: houses close to facilities have different prices.

# %% [markdown]
# **Step 8 — Also compare the means**

# %%
print("Average close house value:", close_values.mean())
print("Average far house value:", far_values.mean())
# Out:
# Average close house value: 246951.98213501245
# Average far house value: 180678.44105790975

# %% [markdown]
# We performed an independent two-sample t-test comparing median house values between houses close to a school or hospital and houses farther away. With a significance level of 5%, the p-value was 3.0064957768591797e-301.
# Since this is **smaller** than 0.05, we **reject** the null hypothesis. Therefore, there is (sufficient/insufficient) evidence that proximity to a school or hospital affects house prices.
